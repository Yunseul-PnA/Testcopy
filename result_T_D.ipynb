# %%
import numpy as np
import matplotlib.pyplot as plt
import pyCloudy as pc
import pyneb as pn
from astropy import units as u
import os
from matplotlib.lines import Line2D
import pandas as pd

# %%
file_path = r'/mnt/c/Users/wlsdl/OneDrive/바탕 화면/Code/Young PNe/models/0010_tb2.dat'
data = pd.read_csv(file_path, skiprows=1, delim_whitespace=True)

column_names = ['N', 'LogL/Lsun', 'LogTeff', 'Logg', 't/yr', 'Menv/Mstar', 'Mstar', 'Log(-dMstar/dt)']
data.columns = column_names
#data 간 information index = 7
data_1_inf = data[0:4]
Mass_1_dat0010_tb2 = data[5:306]
Lum_1_dat0010_tb2 , Teff_1_dat0010_tb2 = Mass_1_dat0010_tb2['LogL/Lsun'].to_numpy().astype(float) , Mass_1_dat0010_tb2['LogTeff'].to_numpy().astype(float)
mass_dat0010_tb2_1 = data_1_inf[0:]['LogL/Lsun'].to_numpy()[0]
print('mass_1  = ', mass_dat0010_tb2_1)

data_2_inf= data[306:313]
Mass_2_dat0010_tb2 = data[313:614]
Lum_2_dat0010_tb2 , Teff_2_dat0010_tb2 = Mass_2_dat0010_tb2['LogL/Lsun'].to_numpy().astype(float) ,Mass_2_dat0010_tb2['LogTeff'].to_numpy().astype(float)

mass_dat0010_tb2_2 = data_2_inf[2:]['LogL/Lsun'].to_numpy()[0]
print('mass_2  = ', mass_dat0010_tb2_2)


data_3_inf = data[614:621]
Mass_3_dat0010_tb2 = data[621:922]
Lum_3_dat0010_tb2 , Teff_3_dat0010_tb2 = Mass_3_dat0010_tb2['LogL/Lsun'].to_numpy().astype(float) ,Mass_3_dat0010_tb2['LogTeff'].to_numpy().astype(float)

mass_dat0010_tb2_3 = data_3_inf[2:]['LogL/Lsun'].to_numpy()[0]
print('mass_3  = ', mass_dat0010_tb2_3)

data_4_inf = data[922:929]
Mass_4_dat0010_tb2 = data[929:1230]
Lum_4_dat0010_tb2 , Teff_4_dat0010_tb2 = Mass_4_dat0010_tb2['LogL/Lsun'].to_numpy().astype(float) ,Mass_4_dat0010_tb2['LogTeff'].to_numpy().astype(float)

mass_dat0010_tb2_4 = data_4_inf[2:]['LogL/Lsun'].to_numpy()[0]
print('mass_4  = ', mass_dat0010_tb2_4)

file_path = r'/home/jin/606_off/Cloudy/'
data_1 = pd.read_csv(file_path + 'evolution_track_Data_Flux.csv', sep=',',header=0)
data_2 = pd.read_csv(file_path + 'BOES.csv', sep=',',header=0)
data_3 = pd.read_csv(file_path + 'Cloudy_data.csv', sep=',',header=0)

mass_1_ratio,mass_2_ratio,mass_3_ratio,mass_4_ratio = data_1['mass_1_ratio'].to_numpy(),data_1['mass_2_ratio'].to_numpy(),data_1['mass_3_ratio'].to_numpy(),data_1['mass_4_ratio'].to_numpy()
name_b, ratio_b,lumin_b, tem_b =  data_2['Boes_Name'].to_numpy(),data_2['Boes_ratio'].to_numpy(),data_2['Boes_Luminosity'].to_numpy(),data_2['Boes_Temperature'].to_numpy()
tem_c , ratio_c = data_3['Temp'].to_numpy(),data_3['Flux_Ratio'].to_numpy(),

# import pandas as pd
# PNe = pd.read_csv(r'Young PNe_1.csv',header=0)
# pn = PNe.iloc[:,[0,1,2,3,4]]

# pn
# h_4859__4861 = pn['4859/4861'].to_numpy()
# h_6560_6563 = pn['6560/6563'].to_numpy()

# tem_r, lum_r = pn['Teff(K)'].to_numpy() , pn['L (Sun)'].to_numpy()
# lum_r =  np.log10(lum_r)
# name_r = pn['Name'].to_numpy()
# ratio_r = pn['6560/6563'].to_numpy()

# He = ['NGC 6741' , 'NGC 6884', 'NGC 6886', 'NGC 6881']  
# group_N = ['H4-1', 'Hu 2 -1', 'Hen2-447']   # No helium
# group_W = ['NGC 2392','M 1 - 8', 'NGC 2346'] #He 6560 O, 6527 X
# group_S = ['J 900', 'NGC 3242']  #He 6560 O, 6527 O ,No Raman 654
# Out:
# mass_1  =  1.000000
# mass_2  =  1.500000
# mass_3  =  2.000000
# mass_4  =  2.500000

# %%
N = 20
rr = np.linspace(1, N, N)
Lumin = np.linspace(35,38,N)
Temp = np.linspace(1.00E+4,3.00E+5,N)
Hd = np.linspace(2,7,N)
later = ['T','L','D']
for i,k in enumerate(later):
    if k =='T':
        ll = 'Tem'
        VV = Temp.copy()
    elif k =='L':
        ll = 'Lum'
        VV = Lumin.copy()
    elif k == 'D':
        ll = 'hden'
        VV = Hd.copy()

    variable_names = ['Lum_Lya','Lum_Lyb',
        'Lum_Ha', 'Lum_Hb', 'Lum_O6', 'Lum_O6_1', 'Lum_O6_2',
        'Lum_O3',
        'Lum_C4', 'Lum_C4_1', 'Lum_C4_2', 'Lum_N5', 'Lum_N5_1', 'Lum_N5_2',
        'Lum_Mg2', 'Lum_Mg2_1', 'Lum_Mg2_2',
        'Lum_He2_949', 'Lum_He2_972', 'Lum_He2_1025', 'Lum_He2_1640',
        'Lum_He2_4339', 'Lum_He2_4859', 'Lum_He2_6527', 'Lum_He2_6560',
        'Nden_HI', 'Nden_HII', 'Nden_OVI', 'Nden_NV', 'Nden_CIV']

    for var_name in variable_names:
        # t = globals()[var_name+'_'+str(k)]
        globals()[var_name+'_'+str(k)] = np.zeros(N) 
        # print(var_name+'_'+str(k))

    # print(Lum_LybLum_Ha_T)


    globals()['ex_'+str(k)] = []
    for ii,nn in enumerate(rr):
        path = r"/home/jin/606_off/Cloudy/New/{}/data_{}/data_{}".format(ll,ii,ii)
        # print(path)
        try:
            Mod = pc.CloudyModel(path)
            globals()['Lum_Lya_'+str(k)][ii] = float(Mod.get_emis_vol('H__1_121567A'))
            globals()['Lum_Lyb_'+str(k)][ii] = float(Mod.get_emis_vol('H__1_102572A'))
            globals()['Lum_Ha_'+str(k)][ii] = float(Mod.get_emis_vol('H__1_656281A'))
            globals()['Lum_Hb_'+str(k)][ii] = float(Mod.get_emis_vol('H__1_486133A'))

            globals()['Lum_O6_'+str(k)][ii] = float(Mod.get_emis_vol('O__6_103191A')) + float(Mod.get_emis_vol('O__6_103762A'))
            globals()['Lum_O6_1_'+str(k)][ii] = float(Mod.get_emis_vol('O__6_103191A'))
            globals()['Lum_O6_2_'+str(k)][ii] = float(Mod.get_emis_vol('O__6_103762A'))
            
            globals()['Lum_O3_'+str(k)][ii] = float(Mod.get_emis_vol('O__3_500684A'))

            globals()['Lum_C4_'+str(k)][ii] = float(Mod.get_emis_vol('C__4_154819A')) + float(Mod.get_emis_vol('C__4_155078A'))
            globals()['Lum_C4_1_'+str(k)][ii] = float(Mod.get_emis_vol('C__4_154819A'))
            globals()['Lum_C4_2_'+str(k)][ii] = float(Mod.get_emis_vol('C__4_155078A'))

            globals()['Lum_N5_'+str(k)][ii] = float(Mod.get_emis_vol('N__5_123882A')) + float(Mod.get_emis_vol('N__5_124280A'))
            globals()['Lum_N5_1_'+str(k)][ii] = float(Mod.get_emis_vol('N__5_123882A'))
            globals()['Lum_N5_2_'+str(k)][ii] = float(Mod.get_emis_vol('N__5_124280A'))

            globals()['Lum_Mg2_'+str(k)][ii] = float(Mod.get_emis_vol('MG_2_279553A')) + float(Mod.get_emis_vol('MG_2_280271A'))
            globals()['Lum_Mg2_1_'+str(k)][ii] = float(Mod.get_emis_vol('MG_2_279553A'))
            globals()['Lum_Mg2_2_'+str(k)][ii] = float(Mod.get_emis_vol('MG_2_280271A'))

            globals()['Lum_He2_949_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_949310A'))
            globals()['Lum_He2_972_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_972108A'))
            globals()['Lum_He2_1025_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_102527A'))  
            globals()['Lum_He2_1640_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_164043A'))

            globals()['Lum_He2_4339_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_433900A'))
            globals()['Lum_He2_4859_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_485900A'))
            globals()['Lum_He2_6527_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_652700A'))
            globals()['Lum_He2_6560_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_656000A'))

            N_H = sum(Mod.dr * Mod.nH)
            frac_C = 2.45E-04
            frac_O = 4.90E-04
            frac_N = 8.51E-05
            frac_Mg = 3.47E-05
            N_HI = sum(Mod.dr * Mod.nH * Mod.get_ionic('H', 0))
            N_HII = sum(Mod.dr * Mod.nH * Mod.get_ionic('H', 1))
            N_OVI = frac_O * sum(Mod.dr * Mod.nH * Mod.get_ionic('O', 5))
            N_NV = frac_N * sum(Mod.dr * Mod.nH * Mod.get_ionic('N', 4))
            N_CIV = frac_C * sum(Mod.dr * Mod.nH * Mod.get_ionic('C', 3))
            globals()['Nden_HI_'+str(k)][ii] = N_HI
            globals()['Nden_HII_'+str(k)][ii] = N_HII 
            globals()['Nden_OVI_'+str(k)][ii] = N_OVI
            globals()['Nden_NV_'+str(k)][ii] = N_NV
            globals()['Nden_CIV_'+str(k)][ii] = N_CIV

        except ValueError:
            globals()['ex_'+str(k)].append(int(nn-1))
            print('error  = %d'%(nn))    
        except AttributeError:
            globals()['ex_'+str(k)].append(int(nn-1))
            print('error  = %d'%(nn))
# Out:
# warng CloudyModel /home/jin/606_off/Cloudy/New/Tem/data_0/data_0: Model aborted
# error  = 1
# warng CloudyModel /home/jin/606_off/Cloudy/New/Tem/data_3/data_3: Model aborted
# error  = 4
# warng CloudyModel /home/jin/606_off/Cloudy/New/Lum/data_1/data_1: Model aborted
# error  = 2
# warng CloudyModel /home/jin/606_off/Cloudy/New/Lum/data_3/data_3: Model aborted
# error  = 4
# warng CloudyModel /home/jin/606_off/Cloudy/New/hden/data_1/data_1: Model aborted
# error  = 2
# warng CloudyModel /home/jin/606_off/Cloudy/New/hden/data_2/data_2: Model aborted
# error  = 3
# warng CloudyModel /home/jin/606_off/Cloudy/New/hden/data_3/data_3: Model aborted
# error  = 4
# error  = 5
# error  = 6
# warng CloudyModel /home/jin/606_off/Cloudy/New/hden/data_6/data_6: Model aborted
# error  = 7
# error  = 8
# error  = 9
# error  = 10

# %%
N = 20
Lumin = np.linspace(35,38,N)
Temp = np.linspace(1.00E+4,3.00E+5,N)
Hd = np.linspace(2,7,N)

later = ['T','L','D']

# print(Lum_He2_6560_T)
for i,k in enumerate(later):
    if k =='T':
        ll = 'Tem'
        Temp = np.delete(Temp,globals()['ex_'+str(k)])
    elif k =='L':
        ll = 'Lum'
        Lumin = np.delete(Lumin,globals()['ex_'+str(k)])
    elif k == 'D':
        ll = 'hden'
        Hd = np.delete(Hd,globals()['ex_'+str(k)])

    variable_names = ['Lum_Lya','Lum_Lyb',
        'Lum_Ha', 'Lum_Hb', 'Lum_O6', 'Lum_O6_1', 'Lum_O6_2',
        'Lum_O3',
        'Lum_C4', 'Lum_C4_1', 'Lum_C4_2', 'Lum_N5', 'Lum_N5_1', 'Lum_N5_2',
        'Lum_Mg2', 'Lum_Mg2_1', 'Lum_Mg2_2',
        'Lum_He2_949', 'Lum_He2_972', 'Lum_He2_1025', 'Lum_He2_1640',
        'Lum_He2_4339', 'Lum_He2_4859', 'Lum_He2_6527', 'Lum_He2_6560',
        'Nden_HI', 'Nden_HII', 'Nden_OVI', 'Nden_NV', 'Nden_CIV']

    for var_name in variable_names:
        globals()[var_name+'_'+str(k)] = np.delete(globals()[var_name+'_'+str(k)] ,globals()['ex_'+str(k)])

# %%
N = 20
rr = np.linspace(1, N, N)
Temp_d = np.linspace(1.00E+4,3.00E+5,N)
later = ['T_den_3','T_den_7']
for i,k in enumerate(later):
    if k =='T_den_3':
        ll = 'Tem_den_3'
        VV = Temp_d.copy()
    elif k =='T_den_7':
        ll = 'Tem_den_7'
        VV = Temp_d.copy()


    variable_names = ['Lum_Lya','Lum_Lyb',
        'Lum_Ha', 'Lum_Hb', 'Lum_O6', 'Lum_O6_1', 'Lum_O6_2',
        'Lum_O3',
        'Lum_C4', 'Lum_C4_1', 'Lum_C4_2', 'Lum_N5', 'Lum_N5_1', 'Lum_N5_2',
        'Lum_Mg2', 'Lum_Mg2_1', 'Lum_Mg2_2',
        'Lum_He2_949', 'Lum_He2_972', 'Lum_He2_1025', 'Lum_He2_1640',
        'Lum_He2_4339', 'Lum_He2_4859', 'Lum_He2_6527', 'Lum_He2_6560',
        'Nden_HI', 'Nden_HII', 'Nden_OVI', 'Nden_NV', 'Nden_CIV']

    for var_name in variable_names:
        # t = globals()[var_name+'_'+str(k)]
        globals()[var_name+'_'+str(k)] = np.zeros(N) 
        # print(var_name+'_'+str(k))

    # print(Lum_LybLum_Ha_T)


    globals()['ex_'+str(k)] = []
    for ii,nn in enumerate(rr):
        path = r"/home/jin/606_off/Cloudy/New/{}/data_{}/data_{}".format(ll,ii,ii)
        print(path)
        try:
            Mod = pc.CloudyModel(path)
            globals()['Lum_Lya_'+str(k)][ii] = float(Mod.get_emis_vol('H__1_121567A'))
            globals()['Lum_Lyb_'+str(k)][ii] = float(Mod.get_emis_vol('H__1_102572A'))
            globals()['Lum_Ha_'+str(k)][ii] = float(Mod.get_emis_vol('H__1_656281A'))
            globals()['Lum_Hb_'+str(k)][ii] = float(Mod.get_emis_vol('H__1_486133A'))

            globals()['Lum_O6_'+str(k)][ii] = float(Mod.get_emis_vol('O__6_103191A')) + float(Mod.get_emis_vol('O__6_103762A'))
            globals()['Lum_O6_1_'+str(k)][ii] = float(Mod.get_emis_vol('O__6_103191A'))
            globals()['Lum_O6_2_'+str(k)][ii] = float(Mod.get_emis_vol('O__6_103762A'))
            
            globals()['Lum_O3_'+str(k)][ii] = float(Mod.get_emis_vol('O__3_500684A'))

            globals()['Lum_C4_'+str(k)][ii] = float(Mod.get_emis_vol('C__4_154819A')) + float(Mod.get_emis_vol('C__4_155078A'))
            globals()['Lum_C4_1_'+str(k)][ii] = float(Mod.get_emis_vol('C__4_154819A'))
            globals()['Lum_C4_2_'+str(k)][ii] = float(Mod.get_emis_vol('C__4_155078A'))

            globals()['Lum_N5_'+str(k)][ii] = float(Mod.get_emis_vol('N__5_123882A')) + float(Mod.get_emis_vol('N__5_124280A'))
            globals()['Lum_N5_1_'+str(k)][ii] = float(Mod.get_emis_vol('N__5_123882A'))
            globals()['Lum_N5_2_'+str(k)][ii] = float(Mod.get_emis_vol('N__5_124280A'))

            globals()['Lum_Mg2_'+str(k)][ii] = float(Mod.get_emis_vol('MG_2_279553A')) + float(Mod.get_emis_vol('MG_2_280271A'))
            globals()['Lum_Mg2_1_'+str(k)][ii] = float(Mod.get_emis_vol('MG_2_279553A'))
            globals()['Lum_Mg2_2_'+str(k)][ii] = float(Mod.get_emis_vol('MG_2_280271A'))

            globals()['Lum_He2_949_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_949310A'))
            globals()['Lum_He2_972_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_972108A'))
            globals()['Lum_He2_1025_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_102527A'))  
            globals()['Lum_He2_1640_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_164043A'))

            globals()['Lum_He2_4339_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_433900A'))
            globals()['Lum_He2_4859_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_485900A'))
            globals()['Lum_He2_6527_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_652700A'))
            globals()['Lum_He2_6560_'+str(k)][ii] = float(Mod.get_emis_vol('HE_2_656000A'))

            N_H = sum(Mod.dr * Mod.nH)
            frac_C = 2.45E-04
            frac_O = 4.90E-04
            frac_N = 8.51E-05
            frac_Mg = 3.47E-05
            N_HI = sum(Mod.dr * Mod.nH * Mod.get_ionic('H', 0))
            N_HII = sum(Mod.dr * Mod.nH * Mod.get_ionic('H', 1))
            N_OVI = frac_O * sum(Mod.dr * Mod.nH * Mod.get_ionic('O', 5))
            N_NV = frac_N * sum(Mod.dr * Mod.nH * Mod.get_ionic('N', 4))
            N_CIV = frac_C * sum(Mod.dr * Mod.nH * Mod.get_ionic('C', 3))
            globals()['Nden_HI_'+str(k)][ii] = N_HI
            globals()['Nden_HII_'+str(k)][ii] = N_HII 
            globals()['Nden_OVI_'+str(k)][ii] = N_OVI
            globals()['Nden_NV_'+str(k)][ii] = N_NV
            globals()['Nden_CIV_'+str(k)][ii] = N_CIV

        except ValueError:
            globals()['ex_'+str(k)].append(int(nn-1))
            print('error  = %d'%(nn))    
        except AttributeError:
            globals()['ex_'+str(k)].append(int(nn-1))
            print('error  = %d'%(nn))
# Out:
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_0/data_0
# warng CloudyModel /home/jin/606_off/Cloudy/New/Tem_den_3/data_0/data_0: Model aborted
# error  = 1
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_1/data_1
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_2/data_2
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_3/data_3
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_4/data_4
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_5/data_5
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_6/data_6
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_7/data_7
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_8/data_8
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_9/data_9
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_10/data_10
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_11/data_11
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_12/data_12
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_13/data_13
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_14/data_14
# /home/jin/606_off/Cloudy/New/Tem_den_3/data_15/data_15
# ...

# %%
Temp_d = np.linspace(1.00E+4,3.00E+5,N)
later = ['T_den_3','T_den_7']

# print(Lum_He2_6560_T)
for i,k in enumerate(later):
    if k =='T_den_3':
        Temp_den3 = np.delete(Temp_d,globals()['ex_'+str(k)])
    elif k =='T_den_7':
        Temp_den7 = np.delete(Temp_d,globals()['ex_'+str(k)])


    variable_names = ['Lum_Lya','Lum_Lyb',
        'Lum_Ha', 'Lum_Hb', 'Lum_O6', 'Lum_O6_1', 'Lum_O6_2',
        'Lum_O3',
        'Lum_C4', 'Lum_C4_1', 'Lum_C4_2', 'Lum_N5', 'Lum_N5_1', 'Lum_N5_2',
        'Lum_Mg2', 'Lum_Mg2_1', 'Lum_Mg2_2',
        'Lum_He2_949', 'Lum_He2_972', 'Lum_He2_1025', 'Lum_He2_1640',
        'Lum_He2_4339', 'Lum_He2_4859', 'Lum_He2_6527', 'Lum_He2_6560',
        'Nden_HI', 'Nden_HII', 'Nden_OVI', 'Nden_NV', 'Nden_CIV']

    for var_name in variable_names:
        globals()[var_name+'_'+str(k)] = np.delete(globals()[var_name+'_'+str(k)] ,globals()['ex_'+str(k)])

# %%
Tem_l = 100000/1e5
Tem_h = 300000/1e5

Lum_h = 100
Lum_l=0

rr = Lum_He2_6560_T / Lum_Ha_T 

fig = plt.figure(1,figsize=(33,7))

plt.subplot(131)

plt.plot(Temp_den3/1e5, Lum_He2_6560_T_den_3 / Lum_Ha_T_den_3 ,'r--',markersize=1,lw=1,label=r'n$_{H} = 10^{3}$ [cm$^{-3}$]')
plt.plot(Temp_den7/1e5, Lum_He2_6560_T_den_7 / Lum_Ha_T_den_7 ,'b--',markersize=1,lw=1,label=r'n$_{H} = 10^{7}$ [cm$^{-3}$]')
plt.plot(Temp/1e5, Lum_He2_6560_T / Lum_Ha_T ,'k--',markersize=1,lw=1,label=r'n$_{H} = 10^{5}$ [cm$^{-3}$]')
size_r = 300
size_b = 300

# Plotting the lines
plt.plot(Temp_den3 / 1e5, Lum_He2_6560_T_den_3 / Lum_Ha_T_den_3, 'r--', markersize=1, lw=1, label=r'n$_{H} = 10^{3}$ [cm$^{-3}$]')
plt.plot(Temp_den7 / 1e5, Lum_He2_6560_T_den_7 / Lum_Ha_T_den_7, 'b--', markersize=1, lw=1, label=r'n$_{H} = 10^{7}$ [cm$^{-3}$]')
plt.plot(Temp / 1e5, Lum_He2_6560_T / Lum_Ha_T, 'k--', markersize=1, lw=1, label=r'n$_{H} = 10^{5}$ [cm$^{-3}$]')

# Plotting the scatter points
def add_text_if_within_limits(x, y, text, xlim, ylim):
    if xlim[0] <= x <= xlim[1] and ylim[0] <= y <= ylim[1]:
        # 0
        plt.text(x, y, text, size=10)

used_labels = set()
xlim = (Tem_l - 0.5, Tem_h + 0.05)
ylim = (0.0, 0.03)
for ii, label in enumerate(name_r):
    x = tem_r[ii] / 1e5
    y = ratio_r[ii] - 0.001
    if label in He:
        if label == 'NGC 6741' and 'Group SR_R' not in used_labels:
            plt.scatter(x, ratio_r[ii], edgecolors='k', facecolors='none', s=size_r, label='Group SR_R')
            add_text_if_within_limits(x, y, label, xlim, ylim)
            used_labels.add('Group SR_R')
        else:
            plt.scatter(x, ratio_r[ii], edgecolors='k', facecolors='none', s=size_r)
            add_text_if_within_limits(x, y, label, xlim, ylim)
    elif label in group_N:
        if 'Group N_R' not in used_labels:
            plt.scatter(x, ratio_r[ii], edgecolors='r', facecolors='none', s=size_r, marker='X', label='Group N_R')
            add_text_if_within_limits(x, y, label, xlim, ylim)
            used_labels.add('Group N_R')
        else:
            plt.scatter(x, ratio_r[ii], edgecolors='r', facecolors='none', s=size_r, marker='X')
            add_text_if_within_limits(x, y, label, xlim, ylim)
    elif label in group_W:
        if 'Group W_R' not in used_labels:
            plt.scatter(x, ratio_r[ii], edgecolors='g', facecolors='none', s=size_r, marker='D', label='Group W_R')
            add_text_if_within_limits(x, y, label, xlim, ylim)
            used_labels.add('Group W_R')
        else:
            plt.scatter(x, ratio_r[ii], edgecolors='g', facecolors='none', s=size_r, marker='D')
            add_text_if_within_limits(x, y, label, xlim, ylim)
    elif label in group_S:
        if 'Group S_R' not in used_labels:
            plt.scatter(x, ratio_r[ii], edgecolors='b', facecolors='none', s=size_r, marker='^', label='Group S_R')
            add_text_if_within_limits(x, y, label, xlim, ylim)
            used_labels.add('Group S_R')
        else:
            plt.scatter(x, ratio_r[ii], edgecolors='b', facecolors='none', s=size_r, marker='^')
            add_text_if_within_limits(x, y, label, xlim, ylim)
    else:
        plt.scatter(x, ratio_r[ii], edgecolors='grey', facecolors='none', s=size_r, marker='*')
        add_text_if_within_limits(x, y, label, xlim, ylim)
used_labels = set()
for ii, label in enumerate(name_b):
    x = tem_b[ii] / 1e5
    y = ratio_b[ii] - 0.0015
    if label in He:
        if label == 'NGC 6886' and 'Group SR_B' not in used_labels:
            plt.scatter(x, ratio_b[ii], edgecolors='k', facecolors='k', s=size_b, label='Group SR_B')
            add_text_if_within_limits(x, y+0.002, label, xlim, ylim)
            used_labels.add('Group SR_B')
        else:
            plt.scatter(x, ratio_b[ii], edgecolors='k', facecolors='k', s=size_b)
            add_text_if_within_limits(x, y, label, xlim, ylim)
    elif label in group_N:
        if 'Group N_B' not in used_labels:
            plt.scatter(x, ratio_b[ii], edgecolors='r', facecolors='r', s=size_b, marker='X', label='Group N_B')
            add_text_if_within_limits(x, y, label, xlim, ylim)
            used_labels.add('Group N_B')
        else:
            plt.scatter(x, ratio_b[ii], edgecolors='r', facecolors='r', s=size_b, marker='X')
            add_text_if_within_limits(x, y, label, xlim, ylim)
    elif label in group_W:
        if 'Group W_B' not in used_labels:
            plt.scatter(x, ratio_b[ii], edgecolors='g', facecolors='g', s=size_b, marker='D', label='Group W_B')
            add_text_if_within_limits(x, y, label, xlim, ylim)
            used_labels.add('Group W_B')
        else:
            plt.scatter(x, ratio_b[ii], edgecolors='g', facecolors='g', s=size_b, marker='D')
            add_text_if_within_limits(x, y, label, xlim, ylim)
    elif label in group_S:
        if 'Group S_B' not in used_labels:
            plt.scatter(x, ratio_b[ii], edgecolors='b', facecolors='b', s=size_b, marker='^', label='Group S_B')
            add_text_if_within_limits(x, y, label, xlim, ylim)
            used_labels.add('Group S_B')
        else:
            plt.scatter(x, ratio_b[ii], edgecolors='b', facecolors='b', s=size_b, marker='^')
            add_text_if_within_limits(x, y, label, xlim, ylim)
    else:
        plt.scatter(x, ratio_b[ii], edgecolors='grey', facecolors='none', s=size_b, marker='*')
        add_text_if_within_limits(x, y, label, xlim, ylim)

plt.ylabel(r'$F_{6560} ~ / ~ F_{\rm{H}\alpha}$', fontsize=25)
plt.ylim(0.0, 0.03)
# Tem_l, Tem_h = 0.5, 2.5  # Sample limits for x-axis
plt.xlim(Tem_l - 0.5, Tem_h + 0.05)
plt.xticks(np.linspace(Tem_l, Tem_h, 5))
plt.xlabel(r'$T_{\rm eff}$ [$10^5 \,$K]', fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.minorticks_on()
plt.grid(True)
# Custom legend lines
custom_lines = [
    Line2D([0], [0], color='r', linestyle='--', label=r'n$_{H} = 10^{3}$ [cm$^{-3}$]'),
    Line2D([0], [0], color='b', linestyle='--', label=r'n$_{H} = 10^{7}$ [cm$^{-3}$]'),
    Line2D([0], [0], color='k', linestyle='--', label=r'n$_{H} = 10^{5}$ [cm$^{-3}$]'),

    Line2D([0], [0], marker='o', color='w', markerfacecolor='none', markeredgewidth=1.5, markeredgecolor='k', markersize=10, label='Group SR_R'),
    Line2D([0], [0], marker='X', color='w', markerfacecolor='none', markeredgewidth=1.5, markeredgecolor='r', markersize=10, label='Group N_R'),
    Line2D([0], [0], marker='D', color='w', markerfacecolor='none', markeredgewidth=1.5, markeredgecolor='g', markersize=10, label='Group W_R'),
    Line2D([0], [0], marker='^', color='w', markerfacecolor='none', markeredgewidth=1.5, markeredgecolor='b', markersize=10, label='Group S_R'),

    Line2D([0], [0], marker='o', color='w', markerfacecolor='k', markersize=10, label='Group SR'),
    Line2D([0], [0], marker='X', color='w', markerfacecolor='r', markersize=10, label='Group N'),
    Line2D([0], [0], marker='D', color='w', markerfacecolor='g', markersize=10, label='Group W'),
    Line2D([0], [0], marker='^', color='w', markerfacecolor='b', markersize=10, label='Group S')
]

plt.plot([], [], ' ', label='')  # Dummy plot with empty label to be able to add legends

second_legend = plt.legend(
    handles=custom_lines[3:], 
    loc='lower right', 
    ncol=2, 
    fontsize=20, 
    bbox_to_anchor=(1, 0.01),  # Adjust as needed to position legend
    borderaxespad=0.,  # Adjust to ensure the legend is within figure bounds
    columnspacing=1.0,  # Increase space between columns
    handletextpad=0.5  # Increase space between legend handle and text
)
plt.gca().add_artist(second_legend)


plt.subplot(132)
plt.plot(Temp_den3/1e5, Lum_He2_1025_T_den_3 /Lum_He2_6560_T_den_3 ,'r--',markersize=10,lw=3,label=r'n$_{H} = 10^{3}$ [cm$^{-3}$]')
plt.plot(Temp/1e5, Lum_He2_1025_T /Lum_He2_6560_T ,'k--',markersize=10,lw=3,label=r'n$_{H} = 10^{5}$ [cm$^{-3}$]')
plt.plot(Temp_den7/1e5, Lum_He2_1025_T_den_7 /Lum_He2_6560_T_den_7 ,'b--',markersize=10,lw=3,label=r'n$_{H} = 10^{7}$ [cm$^{-3}$]')


# plt.axhline(y=(Lum_He2_1025_T_den_3[4:] / Lum_He2_6560_T_den_3[4:]).mean(), xmin=0, xmax=300000/1e5, color='r', linestyle=':')
print('Den 3 mean density is = ', (Lum_He2_1025_T_den_3[4:] / Lum_He2_6560_T_den_3[4:]).mean())

plt.axhline(y=(Lum_He2_1025_T[4:] / Lum_He2_6560_T[4:]).mean(), xmin=0, xmax=300000/1e5, color='k',lw=2,alpha=0.5,linestyle='-')
print('Den 5 mean density is = ', (Lum_He2_1025_T[4:] / Lum_He2_6560_T[4:]).mean())

# plt.axhline(y=(Lum_He2_1025_T_den_7[4:] / Lum_He2_6560_T_den_7[4:]).mean(), xmin=0, xmax=300000/1e5, color='b', linestyle=':')
print('Den 7 mean density is = ', (Lum_He2_1025_T_den_7[4:] / Lum_He2_6560_T_den_7[4:]).mean())


# plt.legend(loc='lower right',fontsize=15)
# plt.yscale('log')

plt.ylim(4,6)
plt.yticks(np.linspace(4,6,5))
plt.ylabel(r'$F_{1025} ~ / ~ F_{6560}$', fontsize=25)
plt.yticks(fontsize=20)


plt.xlim(Tem_l-0.1,Tem_h+0.05)
plt.xticks(np.linspace(Tem_l,Tem_h,5))
plt.xlabel(r'$T_{\rm eff}$ [$10^5 \,$K]',fontsize=25)
plt.xticks(fontsize=20)
plt.minorticks_on()
plt.grid(True)
plt.legend(loc='lower right',fontsize=25)
plt.tight_layout()


plt.subplot(133)
plt.plot(Temp_den3/1e5, Lum_He2_6527_T_den_3 /Lum_He2_6560_T_den_3 ,'r--',markersize=10,lw=3,label=r'n$_{H} = 10^{3}$ [cm$^{-3}$]')
plt.plot(Temp/1e5, Lum_He2_6527_T /Lum_He2_6560_T ,'k--',markersize=10,lw=3,label=r'n$_{H} = 10^{5}$ [cm$^{-3}$]')
plt.plot(Temp_den7/1e5, Lum_He2_6527_T_den_7 /Lum_He2_6560_T_den_7 ,'b--',markersize=10,lw=3,label=r'n$_{H} = 10^{7}$ [cm$^{-3}$]')


# plt.axhline(y=(Lum_He2_1025_T_den_3[4:] / Lum_He2_6560_T_den_3[4:]).mean(), xmin=0, xmax=300000/1e5, color='r', linestyle=':')
print('Den 3 mean density is = ', (Lum_He2_6527_T_den_3[4:] / Lum_He2_6560_T_den_3[4:]).mean())

plt.axhline(y=(Lum_He2_6527_T[4:] / Lum_He2_6560_T[4:]).mean(), xmin=0, xmax=300000/1e5, color='k',lw=2,alpha=0.5,linestyle='-')
print('Den 5 mean density is = ', (Lum_He2_6527_T[4:] / Lum_He2_6560_T[4:]).mean())

# plt.axhline(y=(Lum_He2_1025_T_den_7[4:] / Lum_He2_6560_T_den_7[4:]).mean(), xmin=0, xmax=300000/1e5, color='b', linestyle=':')
print('Den 7 mean density is = ', (Lum_He2_6527_T_den_7[4:] / Lum_He2_6560_T_den_7[4:]).mean())


# plt.legend(loc='lower right',fontsize=15)
# plt.yscale('log')

plt.ylim(0.045,0.05)
# plt.yticks(np.linspace(4,6,5))
plt.ylabel(r'$F_{6527} ~ / ~ F_{6560}$', fontsize=25)
plt.yticks(fontsize=20)


plt.xlim(Tem_l-0.1,Tem_h+0.05)
plt.xticks(np.linspace(Tem_l,Tem_h,5))
plt.xlabel(r'$T_{\rm eff}$ [$10^5 \,$K]',fontsize=25)
plt.xticks(fontsize=20)
plt.minorticks_on()
plt.grid(True)
# plt.legend(loc='lower right',fontsize=25)
plt.tight_layout()


# plt.savefig(r'/mnt/c/Users/wlsdl/OneDrive/바탕 화면/Density_various_T_w_label_v2_with_name.pdf', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 33
#      31 xlim = (Tem_l - 0.5, Tem_h + 0.05)
#      32 ylim = (0.0, 0.03)
# ---> 33 for ii, label in enumerate(name_r):
#      34     x = tem_r[ii] / 1e5
#      35     y = ratio_r[ii] - 0.001
#
# NameError: name 'name_r' is not defined

# %%
tem_r
# Out:
# array([170000.     , 127452.     ,  32500.     , 107398.9412 ,
#        152000.     ,  98401.11058,  79799.46873,  80000.     ,
#        129640.     , 160694.1253 ,  57543.99373,  80000.     ])

# %%
Tem_l = 100000/1e5
Tem_h = 300000/1e5

Lum_h = 100
Lum_l=0

rr = Lum_He2_6560_T / Lum_Ha_T 

fig = plt.figure(1,figsize=(10,7))


# size_r = 300
# size_b = 300
# # Plotting the lines
plt.plot(Temp_den3 / 1e5, Lum_He2_6560_T_den_3 / Lum_Ha_T_den_3, 'r--', markersize=1, lw=3, label=r'n$_{H} = 10^{3}$ [cm$^{-3}$]')
plt.plot(Temp_den7 / 1e5, Lum_He2_6560_T_den_7 / Lum_Ha_T_den_7, 'b--', markersize=1, lw=3, label=r'n$_{H} = 10^{7}$ [cm$^{-3}$]')
plt.plot(Temp / 1e5, Lum_He2_6560_T / Lum_Ha_T, 'k--', markersize=1, lw=3, label=r'n$_{H} = 10^{5}$ [cm$^{-3}$]')

# Plotting the scatter points
def add_text_if_within_limits(x, y, text, xlim, ylim):
    if xlim[0] <= x <= xlim[1] and ylim[0] <= y <= ylim[1]:
        0
        # plt.text(x, y, text, size=10)

used_labels = set()
xlim = (Tem_l - 0.5, Tem_h + 0.05)
ylim = (0.0, 0.03)

size_sr = 20
size_ot = 18
# for ii, label in enumerate(name_r):
#     bb = np.where(name_b == label)[0] 
#     if label in name_b :  
#         if label in He:
#             # Check if the current label is 'NGC 6741' and 'Group SR_R' has not been used yet
#             if label == 'NGC 6741' and 'Group SR_R' not in used_labels:
#                 plt.plot(tem_r[ii] / 1e5, ratio_b[bb[0]], 'ro', markeredgecolor='k', markersize=size_sr, label='Group SR_R')
#                 used_labels.add('Group SR_R')  # Add 'Group SR_R' to used labels
#             else:
#                 # For other cases in 'He' group, plot with different markers
#                 if label == 'NGC 6886':
#                     plt.plot(tem_r[ii] / 1e5, ratio_b[bb], 'go',markeredgecolor='k', markersize=size_sr)
#                 elif label == 'NGC 6884':
#                     plt.plot(tem_r[ii] / 1e5, ratio_b[bb], 'bo',markeredgecolor='k', markersize=size_sr)
#                 else:
#                     plt.plot(tem_r[ii] / 1e5, ratio_b[bb], 'yo',markeredgecolor='k', markersize=size_sr)
        
#         elif label in group_N:
#             if 'Group N' not in used_labels:  # Check if 'Group N' label has been used
#                 plt.plot(tem_r[ii] / 1e5, ratio_b[bb], 'kX', markersize=size_ot, label='Group N')
#                 used_labels.add('Group N')  # Add 'Group N' to used labels
#             else:
#                 plt.plot(tem_r[ii] / 1e5, ratio_b[bb], 'kX', markersize=size_ot)
        
#         elif label in group_S:
#             if 'Group S' not in used_labels:  # Check if 'Group S' label has been used
#                 plt.plot(tem_r[ii] / 1e5, ratio_b[bb], 'k^', markersize=size_ot, label='Group S')
#                 used_labels.add('Group S')  # Add 'Group S' to used labels
#             else:
#                 plt.plot(tem_r[ii] / 1e5, ratio_b[bb], 'k^', markersize=size_ot)
        
#         elif label in group_W:
#             if 'Group W' not in used_labels:  # Check if 'Group W' label has been used
#                 plt.plot(tem_r[ii] / 1e5, ratio_b[bb], 'kD', markersize=size_ot, label='Group W')
#                 used_labels.add('Group W')  # Add 'Group W' to used labels
#             else:
#                 plt.plot(tem_r[ii] / 1e5, ratio_b[bb], 'kD', markersize=size_ot)
    
#     else:
#         print(label)
#         if label in He:
#             # Check if the current label is 'NGC 6741' and 'Group SR_R' has not been used yet
#             if label == 'NGC 6741' and 'Group SR_R' not in used_labels:
#                 plt.plot(tem_r[ii] / 1e5, ratio_r[ii], 'ro', markersize=size_sr, label='Group SR_R', markerfacecolor='none')
#                 used_labels.add('Group SR_R')  # Add 'Group SR_R' to used labels
#             else:
#                 plt.plot(tem_r[ii] / 1e5, ratio_r[ii], 'yo', markersize=size_sr, markerfacecolor='none')
                
#         elif label in group_N:
#             if 'Group N' not in used_labels:  # Check if 'Group N' label has been used
#                 plt.plot(tem_r[ii] / 1e5, ratio_r[ii], 'kX', markersize=size_ot, label='Group N', markerfacecolor='none')
#                 used_labels.add('Group N')  # Add 'Group N' to used labels
#             else:
#                 plt.plot(tem_r[ii] / 1e5, ratio_r[ii], 'kX', markersize=size_ot, markerfacecolor='none')
                
#         elif label in group_S:
#             if 'Group S' not in used_labels:  # Check if 'Group S' label has been used
#                 plt.plot(tem_r[ii] / 1e5, ratio_r[ii], 'k^', markersize=size_ot, label='Group S', markerfacecolor='none')
#                 used_labels.add('Group S')  # Add 'Group S' to used labels
#             else:
#                 plt.plot(tem_r[ii] / 1e5, ratio_r[ii], 'k^', markersize=size_ot, markerfacecolor='none')
                
#         elif label in group_W:
#             if 'Group W' not in used_labels:  # Check if 'Group W' label has been used
#                 plt.plot(tem_r[ii] / 1e5, ratio_r[ii], 'kD', markersize=size_ot, label='Group W', markerfacecolor='none')
#                 used_labels.add('Group W')  # Add 'Group W' to used labels
#             else:
#                 plt.plot(tem_r[ii] / 1e5, ratio_r[ii], 'kD', markersize=size_ot, markerfacecolor='none')
        

plt.ylabel(r'$F_{6560} ~ / ~ F_{\rm{H}\alpha}$', fontsize=25)
plt.ylim(0.0, 0.03)
# Tem_l, Tem_h = 0.5, 2.5  # Sample limits for x-axis
plt.xlim(Tem_l - 0.5, Tem_h + 0.05)
plt.xticks(np.linspace(Tem_l, Tem_h, 5))
plt.xlabel(r'$T_{\rm eff}$ [$10^5 \,$K]', fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

custom_lines = [
    Line2D([0], [0], color='r', linestyle='--', label=r'n$_{H} = 10^{3}$ [cm$^{-3}$]'),
    Line2D([0], [0], color='k', linestyle='--', label=r'n$_{H} = 10^{5}$ [cm$^{-3}$]'),
    Line2D([0], [0], color='b', linestyle='--', label=r'n$_{H} = 10^{7}$ [cm$^{-3}$]'),


    Line2D([0], [0], marker='X', color='w', markerfacecolor='k', markersize=10, label='Group N'),
    Line2D([0], [0], marker='D', color='w', markerfacecolor='k', markersize=10, label='Group W'),
    Line2D([0], [0], marker='^', color='w', markerfacecolor='k', markersize=10, label='Group S'),
    Line2D([0], [0], marker='o', color='w', markerfacecolor='k', markersize=10, label='Group SR'),

]


# plt.plot([], [], ' ', label='') 
# first_legend = plt.legend(handles=custom_lines[:3], loc='lower right', bbox_to_anchor=(1, 0.18), ncol=1,handlelength=2.5,fontsize=22)
# plt.gca().add_artist(first_legend)
second_legend = plt.legend(handles=custom_lines[3:], loc='lower right', bbox_to_anchor=(1, 0.01), ncol=2,fontsize=20)
plt.gca().add_artist(second_legend)

plt.minorticks_on()
plt.grid(True)


plt.savefig(r'/mnt/c/Users/wlsdl/OneDrive/바탕 화면/Density_vs_Temp_left.pdf',bbox_inches='tight')

# %%
fig = plt.figure(1,figsize=(7,7))

plt.plot(Temp_den3/1e5, Lum_He2_1025_T_den_3 /Lum_He2_6560_T_den_3 ,'r--',markersize=10,lw=3,label=r'n$_{H} = 10^{3}$ [cm$^{-3}$]')
plt.plot(Temp/1e5, Lum_He2_1025_T /Lum_He2_6560_T ,'k--',markersize=10,lw=3,label=r'n$_{H} = 10^{5}$ [cm$^{-3}$]')
plt.plot(Temp_den7/1e5, Lum_He2_1025_T_den_7 /Lum_He2_6560_T_den_7 ,'b--',markersize=10,lw=3,label=r'n$_{H} = 10^{7}$ [cm$^{-3}$]')


# plt.axhline(y=(Lum_He2_1025_T_den_3[4:] / Lum_He2_6560_T_den_3[4:]).mean(), xmin=0, xmax=300000/1e5, color='r', linestyle=':')
print('Den 3 mean density is = ', (Lum_He2_1025_T_den_3[4:] / Lum_He2_6560_T_den_3[4:]).mean())

plt.axhline(y=(Lum_He2_1025_T[4:] / Lum_He2_6560_T[4:]).mean(), xmin=0, xmax=300000/1e5, color='k',lw=2,alpha=0.5,linestyle='-')
print('Den 5 mean density is = ', (Lum_He2_1025_T[4:] / Lum_He2_6560_T[4:]).mean())

# plt.axhline(y=(Lum_He2_1025_T_den_7[4:] / Lum_He2_6560_T_den_7[4:]).mean(), xmin=0, xmax=300000/1e5, color='b', linestyle=':')
print('Den 7 mean density is = ', (Lum_He2_1025_T_den_7[4:] / Lum_He2_6560_T_den_7[4:]).mean())


# plt.legend(loc='lower right',fontsize=15)
# plt.yscale('log')

plt.ylim(4,6)
plt.yticks(np.linspace(4,6,5))
plt.ylabel(r'$F_{1025} ~ / ~ F_{6560}$', fontsize=25)
plt.yticks(fontsize=20)


plt.xlim(Tem_l - 0.5, Tem_h + 0.05)
plt.xticks(np.linspace(Tem_l,Tem_h,5))
plt.xlabel(r'$T_{*}$ [$10^5 \,$K]',fontsize=25)
plt.xticks(fontsize=20)
plt.minorticks_on()
plt.grid(True)
plt.legend(loc='lower right',fontsize=25)
plt.tight_layout()

plt.savefig(r'/mnt/c/Users/wlsdl/OneDrive/바탕 화면/Density_vs_Temp_right.pdf',bbox_inches='tight')
# Out:
# Den 3 mean density is =  4.927010629664574
# Den 5 mean density is =  5.15118302601527
# Den 7 mean density is =  5.41832127666978

# %%
fig = plt.figure(1,figsize=(7,7))

plt.plot(Temp_den3/1e5, Lum_He2_6560_T_den_3/Lum_He2_6527_T_den_3  ,'r--',markersize=10,lw=3,label=r'n$_{H} = 10^{3}$ [cm$^{-3}$]')
plt.plot(Temp/1e5,Lum_He2_6560_T/ Lum_He2_6527_T  ,'k--',markersize=10,lw=3,label=r'n$_{H} = 10^{5}$ [cm$^{-3}$]')
plt.plot(Temp_den7/1e5, Lum_He2_6560_T_den_7/Lum_He2_6527_T_den_7  ,'b--',markersize=10,lw=3,label=r'n$_{H} = 10^{7}$ [cm$^{-3}$]')


# plt.axhline(y=(Lum_He2_1025_T_den_3[4:] / Lum_He2_6560_T_den_3[4:]).mean(), xmin=0, xmax=300000/1e5, color='r', linestyle=':')
print('Den 3 mean density is = ', ( Lum_He2_6560_T_den_3[4:]/Lum_He2_6527_T_den_3[4:] ).mean())

# plt.axhline(y=( Lum_He2_6560_T[4:]/Lum_He2_6527_T[4:] ).mean(), xmin=0, xmax=300000/1e5, color='k',lw=2,alpha=0.5,linestyle='-')
print('Den 5 mean density is = ', ( Lum_He2_6560_T[4:]/Lum_He2_6527_T[4:] ).mean())

# plt.axhline(y=(Lum_He2_1025_T_den_7[4:] / Lum_He2_6560_T_den_7[4:]).mean(), xmin=0, xmax=300000/1e5, color='b', linestyle=':')
print('Den 7 mean density is = ', (Lum_He2_6560_T_den_7[4:]/Lum_He2_6527_T_den_7[4:]).mean())


plt.legend(loc='lower right',fontsize=25)
# plt.yscale('log')

plt.ylim(19,21.5)
# plt.yticks(np.linspace(4,6,5))
plt.ylabel(r'$F_{6560} ~ / ~ F_{6527}$', fontsize=25)
plt.yticks(fontsize=20)

plt.yticks(fontsize=20)


plt.xlim(Tem_l - 0.5, Tem_h + 0.05)
plt.xticks(np.linspace(Tem_l,Tem_h,5))
plt.xlabel(r'$T_{*}$ [$10^5 \,$K]',fontsize=25)
plt.xticks(fontsize=20)
plt.minorticks_on()
plt.grid(True)

plt.tight_layout()

plt.savefig(r'/mnt/c/Users/wlsdl/OneDrive/바탕 화면/Density_vs_Temp_6560_6527_label.pdf',bbox_inches='tight')
# Out:
# Den 3 mean density is =  20.592354327583674
# Den 5 mean density is =  21.024279604242672
# Den 7 mean density is =  21.295985570265902

# %%
fig = plt.figure(1,figsize=(7,7))

plt.plot(Temp_den3/1e5,Lum_C4_1_T_den_3/ Lum_C4_2_T_den_3  ,'ro--',markersize=10,lw=3,label=r'n$_{H} = 10^{3}$ [cm$^{-3}$]')
plt.plot(Temp/1e5, Lum_C4_1_T/Lum_C4_2_T  ,'ko--',markersize=10,lw=3,label=r'n$_{H} = 10^{5}$ [cm$^{-3}$]')
plt.plot(Temp_den7/1e5,Lum_C4_1_T_den_7 /  Lum_C4_2_T_den_7 ,'bo--',markersize=10,lw=3,label=r'n$_{H} = 10^{7}$ [cm$^{-3}$]')


# plt.axhline(y=(Lum_He2_1025_T_den_3[4:] /Lum_C4_1_T_den_3[4:]).mean(), xmin=0, xmax=300000/1e5, color='r', linestyle=':')
print('Lum 35 mean density is = ', (Lum_C4_1_T_den_3[4:]/ Lum_C4_2_T_den_3[4:] ).mean())

# plt.axhline(y=( Lum_C4_1_T[4:]/Lum_C4_2_T[4:] ).mean(), xmin=0, xmax=300000/1e5, color='k', linestyle='-',alpha=0.5)
print('Lum 37 mean density is = ', (Lum_C4_1_T[4:]/Lum_C4_2_T[4:] ).mean())

# plt.axhline(y=(Lum_He2_1025_T_den_7[4:] /Lum_C4_1_T_den_7[4:]).mean(), xmin=0, xmax=300000/1e5, color='b', linestyle=':')
print('Lum 38 mean density is = ', (Lum_C4_1_T_den_7[4:]/Lum_C4_2_T_den_7[4:] ).mean())


plt.legend(loc='upper right',fontsize=25)
# plt.yscale('log')
# plt.ylim(19,21.5)
# plt.yticks(np.linspace(4,6,5))
plt.ylabel(r'$F_{1548} ~ / ~ F_{1551}$', fontsize=25)
plt.yticks([1.6,1.8,2.0,2.2,2.4],fontsize=20)
plt.ylim(1.55,2.45)

plt.xlim(Tem_l - 0.05, Tem_h + 0.05)
plt.xticks(np.linspace(Tem_l,Tem_h,5))
plt.xlabel(r'$T_{*}$ [$10^5 \,$K]',fontsize=25)
plt.xticks(fontsize=20)
plt.minorticks_on()
plt.grid(True)

plt.tight_layout()

# plt.savefig(r'/mnt/c/Users/wlsdl/OneDrive/바탕 화면/Lum_vs_Den_doublet_ratio_.pdf',bbox_inches='tight')
# Out:
# Lum 35 mean density is =  1.9769180197700984
# Lum 37 mean density is =  1.9827028496455679
# Lum 38 mean density is =  1.9855147383961043

# %%
fig, ax1 = plt.subplots(figsize=(12, 8))

# 온도 플롯 (왼쪽 y축)
color = 'tab:red'
ax1.set_xlabel('Radius [kpc]', fontsize=20)
ax1.set_ylabel('Temperature [K]', fontsize=20)
ax1.plot(Mod.radius/kpc, Mod.te, color=color, label=r'T$_{e}$')
ax1.tick_params(axis='y', labelsize=20)
ax1.tick_params(axis='x', labelsize=20)
ax1.minorticks_on()
ax1.set_xlim(0,15)
ax1.set_yscale('log')
plt.legend(fontsize=20)

# 밀도 플롯을 위한 두 번째 y축 생성
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Density [cm$^{-3}$]', fontsize=20)
ax2.plot(Mod.radius/kpc, Mod.ne, color=color, label=r'n$_{e}$')
color = 'tab:green'
ax2.plot(Mod.radius/kpc, Mod.nH, color=color, label=r'n$_{H}$')
ax2.tick_params(axis='y', labelsize=20)
ax2.set_xlim(0,15)
ax2.set_yscale('log')

# 레이아웃 조정
fig.tight_layout()
plt.legend()

# ax1과 ax2의 레전드 합치기
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right', fontsize=20)

# ax2의 레전드 제거
ax2.get_legend().remove()
ax1.set_ylim(top=4e5,bottom=100)
ax2.set_ylim(top=0.4)
ax1.grid(True,linestyle='--')
print('H I',Lum_Lya, N_HI)
print('O VI',Lum_O6, N_OVI)
print('C IV',Lum_C4, N_CIV)
print('N V',Lum_N5, N_NV)
print('Mg II',Lum_Mg2, N_MgII)

def format_scientific(number):
    exponent = int(np.log10(number))
    mantissa = number / 10**exponent
    return f'{mantissa:.2f} \\times 10^{{{exponent}}}'

# 로그 스케일에서 균일한 간격을 위한 y 좌표 계산
y_base = 2e3
y_factor = 0.6  # 간격 조절을 위한 인자
y_coords = [y_base * y_factor**i for i in range(5)]

ax1.text(8, 2e5, r'$\rm L_{\rm AGN} = 10^{42} ~ \rm erg \, \rm s^{-1}$', fontsize=20)
ax1.text(8, 1e5, r'$\rm N_{H} = 5 \times 10^{21} ~ \rm cm^{-2}$', fontsize=20)

di = 2
ax1.text(1.7, y_coords[0] , r'Luminousity', fontsize=20)
ax1.text(5.2, y_coords[0] , r'Column Density', fontsize=20)

labels = ['Ly$\\alpha$', 'O VI', 'C IV', 'N V', 'Mg II']
luminosities = [Lum_Lya, Lum_O6, Lum_C4, Lum_N5, Lum_Mg2]
column_densities = [N_HI, N_OVI, N_CIV, N_NV, N_MgII]

for i, (label, lum, col_den) in enumerate(zip(labels, luminosities, column_densities)):
    ax1.text(0.5, y_coords[i]/di, f'{label} :', fontsize=15)
    ax1.text(1.5, y_coords[i]/di , r'$\sim ~ {} ~ \rm erg \, \rm s^{{-1}}$'.format(format_scientific(lum)), fontsize=15)
    ax1.text(5.3, y_coords[i]/di , r'$\sim ~ {} ~ \rm cm^{{-2}}$'.format(format_scientific(col_den)), fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       5 ax1.set_xlabel('Radius [kpc]', fontsize=20)
#       6 ax1.set_ylabel('Temperature [K]', fontsize=20)
# ----> 7 ax1.plot(Mod.radius/kpc, Mod.te, color=color, label=r'T$_{e}$')
#       8 ax1.tick_params(axis='y', labelsize=20)
#       9 ax1.tick_params(axis='x', labelsize=20)
#
# NameError: name 'kpc' is not defined
